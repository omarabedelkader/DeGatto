# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive') 
df = pd.read_excel("/content/drive/MyDrive/DeGatto Project/balouta/Copy of Output Womens Clothing E-Commerce Reviews.xlsx")
# Out:
# Mounted at /content/drive

# %%
df.drop(['Clothing ID', 'Sentiment', 'Rating', 'Recommended IND', 'Longevity'], axis= 1, inplace=True)
df.dropna(how='all', inplace = True)

# %%
df
# Out:
#                                               ReviewText  Size Material  \
# 0      i am in need of easy comfortable tops for ever...  NEG.      NaN
# 1      i read the previous reviews and had hoped that...   NaN     POS.
# 2      this is exactly what i was expecting cute comf...   NaN      NaN
# 3      this dress is gorgeous i love it i bought it t...  POS.      NaN
# 4      love this top made with 100 cotton a vintage l...  POS.      NaN
# ...                                                  ...   ...      ...
# 23380  i was very happy to snag this dress at such a ...   NaN      POS
# 23381  it reminds me of maternity clothes soft stretc...   NaN      POS
# 23382  this fit well but the top was very see through...   POS      NEG
# 23383  i bought this dress for a wedding i have this ...   NEG      NaN
# 23384  this dress in a lovely platinum is feminine an...   POS      NaN
#
#       Design Comfort
# 0        NaN    POS.
# 1        NaN    POS.
# 2       POS.    POS.
# ...

# %%
df_review = df['ReviewText']
df_rest = df.drop('ReviewText', axis = 1)
df_rest
# Out:
#        Size Material Design Comfort
# 0      NEG.      NaN    NaN    POS.
# 1       NaN     POS.    NaN    POS.
# 2       NaN      NaN   POS.    POS.
# 3      POS.      NaN   POS.    POS.
# 4      POS.      NaN    NaN    POS.
# ...     ...      ...    ...     ...
# 23380   NaN      POS    POS     POS
# 23381   NaN      POS    NaN     NaN
# 23382   POS      NEG    NaN     NaN
# 23383   NEG      NaN    NaN     NaN
# 23384   POS      NaN    NaN     POS
#
# [22639 rows x 4 columns]

# %%
df_rest.dropna(how='all', inplace = True)

# %%
df_rest
# Out:
#        Size Material Design Comfort
# 0      NEG.      NaN    NaN    POS.
# 1       NaN     POS.    NaN    POS.
# 2       NaN      NaN   POS.    POS.
# 3      POS.      NaN   POS.    POS.
# 4      POS.      NaN    NaN    POS.
# ...     ...      ...    ...     ...
# 23380   NaN      POS    POS     POS
# 23381   NaN      POS    NaN     NaN
# 23382   POS      NEG    NaN     NaN
# 23383   NEG      NaN    NaN     NaN
# 23384   POS      NaN    NaN     POS
#
# [2891 rows x 4 columns]

# %%
df_rest.fillna("no", inplace = True)

# %%
df_review = pd.DataFrame(df_review)
df_review
# Out:
#                                               ReviewText
# 0      i am in need of easy comfortable tops for ever...
# 1      i read the previous reviews and had hoped that...
# 2      this is exactly what i was expecting cute comf...
# 3      this dress is gorgeous i love it i bought it t...
# 4      love this top made with 100 cotton a vintage l...
# ...                                                  ...
# 23380  i was very happy to snag this dress at such a ...
# 23381  it reminds me of maternity clothes soft stretc...
# 23382  this fit well but the top was very see through...
# 23383  i bought this dress for a wedding i have this ...
# 23384  this dress in a lovely platinum is feminine an...
#
# [22639 rows x 1 columns]

# %%
'''
['NEG.', 'no', 'POS.', 'NEU.', 'POS', 'NEG', 'NEU']
['no', 'POS.', 'NEU.', 'NEG.', 'POS..', 'POS', 'NEG', 'NEU', 'Pos', 'POS ']
['no', 'NEG.', 'POS.', 'NEU.', 'NEG', 'NEU', 'POS']
['no', 'POS.', 'NEU.', 'NEG.', 'POS', 'NEG', 'NEU', 'NEEG', 'PO']
['POS.', 'POS. ', 'no', 'NEG.', 'NEU.', 'POS', 'NEG', 'POQ', 'NEU']
'''
# Out:
# "\n['NEG.', 'no', 'POS.', 'NEU.', 'POS', 'NEG', 'NEU']\n['no', 'POS.', 'NEU.', 'NEG.', 'POS..', 'POS', 'NEG', 'NEU', 'Pos', 'POS ']\n['no', 'NEG.', 'POS.', 'NEU.', 'NEG', 'NEU', 'POS']\n['no', 'POS.', 'NEU.', 'NEG.', 'POS', 'NEG', 'NEU', 'NEEG', 'PO']\n['POS.', 'POS. ', 'no', 'NEG.', 'NEU.', 'POS', 'NEG', 'POQ', 'NEU']\n"

# %%
df_rest.replace(["NEG.","NEG","POS", "POS.","NEU", "NEU.", "POS..", "Pos", "POS ", "PO", "POS. ", 'NEEG', 'POQ', 'NO', ' '],
           ["neg", "neg", "pos", "pos", "neu", "neu", "pos", "pos", "pos", "pos", "pos", 'neg', 'pos', 'no', ''], 
           inplace = True)

# %%
df_rest.Size.unique()
# Out:
# array(['neg', 'no', 'pos', 'neu'], dtype=object)

# %%
df_rest.Material.unique()
# Out:
# array(['no', 'pos', 'neu', 'neg'], dtype=object)

# %%
df_rest.Design.unique()
# Out:
# array(['no', 'pos', 'neu', 'neg'], dtype=object)

# %%
df_rest.Comfort.unique()
# Out:
# array(['pos', 'neg', 'no', 'neu'], dtype=object)

# %%
df_final = df_review.join(df_rest)
df = df_final.dropna()
df = df.reset_index()

# %%
df.drop(['index'], axis = 1, inplace = True)

# %%
df.replace

# %%
# !pip install xlsxwriter
with pd.ExcelWriter('/content/drive/MyDrive/DeGatto Project/EDA + Models/Aspect Annotated Data.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Sheet1')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 KB 8.5 MB/s eta 0:00:00
# ...
