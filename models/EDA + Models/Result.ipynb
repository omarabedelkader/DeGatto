# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_1_log = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output.xlsx", sheet_name = 'Logistic Regression')
df_1_mnb = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output.xlsx", sheet_name = 'Multinomial Naive Bayes')
df_1_svm = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output.xlsx", sheet_name = 'SVM')

df_2_log = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output 1.xlsx", sheet_name = 'Logistic Regression')
df_2_mnb = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output 1.xlsx", sheet_name = 'Multinomial Naive Bayes')
df_2_svm = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output 1.xlsx", sheet_name = 'SVM')

df_3_svm = pd.read_excel("/content/drive/MyDrive/DeGatto Project/EDA + Models/First Output 3.xlsx", sheet_name = 'SVM')

# %%
df_1_log.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)
df_1_mnb.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)
df_1_svm.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)

df_2_log.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)
df_2_mnb.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)
df_2_svm.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)

df_3_svm.drop(['Unnamed: 0', 'Precision Train', 'Precision Test', 'Recall Train', 'Recall Test', 'F1 Score Train', 'F1 Score Test'], axis = 1, inplace = True)

# %%
df_1_log
# Out:
#     Output Predicted Vectorization Method  Test Size  C value  Max Iterations  \
# 0            Comfort               TF-IDF        0.3      2.0           400.0
# 1            Comfort               TF-IDF        0.3      1.5           400.0
# 2            Comfort               TF-IDF        0.3      1.0           400.0
# 3            Comfort               TF-IDF        0.3      0.5           400.0
# 4            Comfort               TF-IDF        0.3      2.0           300.0
# ..               ...                  ...        ...      ...             ...
# 795             Size     Count Vectorizer        0.1      0.5           200.0
# 796             Size     Count Vectorizer        0.1      2.0           100.0
# 797             Size     Count Vectorizer        0.1      1.5           100.0
# 798             Size     Count Vectorizer        0.1      1.0           100.0
# 799             Size     Count Vectorizer        0.1      0.5           100.0
#
# ...

# %% [markdown]
# # Logistic

# %%
feat_1 = df_1_log[df_1_log['Output Predicted'] == 'Longevity']
feat_2 = df_2_log[df_2_log['Output Predicted'] == 'Longevity']

feat_1_cv = feat_1[feat_1['Vectorization Method'] == 'Count Vectorizer'] ##
feat_1_tf = feat_1[feat_1['Vectorization Method'] == 'TF-IDF']
feat_2_cv = feat_2[feat_2['Vectorization Method'] == 'Count Vectorizer']
feat_2_tf = feat_2[feat_2['Vectorization Method'] == 'TF-IDF']

# %%
feat_1_cv.loc[feat_1_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                            0.1
# C value                              2.0
# Max Iterations                     400.0
# Accuracy Train                       1.0
# Accuracy Test                   0.995418
# Name: 720, dtype: object

# %%
feat_1_cv[(feat_1_cv["C value"] == 1.000) & (feat_1_cv["Max Iterations"] == 100)]
# Out:
#     Output Predicted Vectorization Method  Test Size  C value  Max Iterations  \
# 94         Longevity     Count Vectorizer       0.30      1.0           100.0
# 254        Longevity     Count Vectorizer       0.25      1.0           100.0
# 414        Longevity     Count Vectorizer       0.20      1.0           100.0
# 574        Longevity     Count Vectorizer       0.15      1.0           100.0
# 734        Longevity     Count Vectorizer       0.10      1.0           100.0
#
#      Accuracy Train  Accuracy Test
# 94              1.0       0.993125
# 254             1.0       0.993581
# 414             1.0       0.994842
# 574             1.0       0.995416
# 734             1.0       0.995418

# %%
feat_2_cv.loc[feat_2_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                           0.15
# C value                              0.1
# Max Iterations                     100.0
# Accuracy Train                  0.999326
# Accuracy Test                   0.993888
# Name: 320, dtype: object

# %%
feat_2_cv[(feat_2_cv["C value"] == 1.000) & (feat_2_cv["Max Iterations"] == 100)]
# Out:
# Empty DataFrame
# Columns: [Output Predicted, Vectorization Method, Test Size, C value, Max Iterations, Accuracy Train, Accuracy Test]
# Index: []

# %%
feat_1_tf.loc[feat_1_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                     0.1
# C value                       2.0
# Max Iterations              400.0
# Accuracy Train           0.999745
# Accuracy Test            0.997709
# Name: 704, dtype: object

# %%
feat_1_tf[(feat_1_tf["C value"] == 1.000) & (feat_1_tf["Max Iterations"] == 100)]
# Out:
#     Output Predicted Vectorization Method  Test Size  C value  Max Iterations  \
# 78         Longevity               TF-IDF       0.30      1.0           100.0
# 238        Longevity               TF-IDF       0.25      1.0           100.0
# 398        Longevity               TF-IDF       0.20      1.0           100.0
# 558        Longevity               TF-IDF       0.15      1.0           100.0
# 718        Longevity               TF-IDF       0.10      1.0           100.0
#
#      Accuracy Train  Accuracy Test
# 78         0.999017       0.996944
# 238        0.998930       0.997707
# 398        0.998997       0.997135
# 558        0.999056       0.997708
# 718        0.998981       0.997709

# %%
feat_2_tf.loc[feat_2_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                     0.1
# C value                       0.1
# Max Iterations              100.0
# Accuracy Train            0.99223
# Accuracy Test            0.993127
# Name: 248, dtype: object

# %%
feat_2_tf[(feat_1_tf["C value"] == 1.000) & (feat_2_tf["Max Iterations"] == 100)]
# Out:
# <ipython-input-213-d50f032eb463>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   feat_2_tf[(feat_1_tf["C value"] == 1.000) & (feat_2_tf["Max Iterations"] == 100)]
# Empty DataFrame
# Columns: [Output Predicted, Vectorization Method, Test Size, C value, Max Iterations, Accuracy Train, Accuracy Test]
# Index: []

# %% [markdown]
# # MNB

# %%
feat_1 = df_1_mnb[df_1_mnb['Output Predicted'] == 'Longevity']
feat_2 = df_2_mnb[df_2_mnb['Output Predicted'] == 'Longevity']

feat_1_cv = feat_1[feat_1['Vectorization Method'] == 'Count Vectorizer'] ##
feat_1_tf = feat_1[feat_1['Vectorization Method'] == 'TF-IDF']
feat_2_cv = feat_2[feat_2['Vectorization Method'] == 'Count Vectorizer']
feat_2_tf = feat_2[feat_2['Vectorization Method'] == 'TF-IDF']

# %%
feat_1_cv.loc[feat_1_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                            0.1
# Alpha                                0.0
# Accuracy Train                   0.99223
# Accuracy Test                   0.997709
# Name: 325, dtype: object

# %%
feat_1_cv[(feat_1_cv["Alpha"] == 1.00)]
# Out:
#     Output Predicted Vectorization Method  Test Size  Alpha  Accuracy Train  \
# 225        Longevity     Count Vectorizer       0.10    1.0        0.985352
# 226        Longevity     Count Vectorizer       0.15    1.0        0.985840
# 227        Longevity     Count Vectorizer       0.20    1.0        0.984668
# 228        Longevity     Count Vectorizer       0.25    1.0        0.984105
# 229        Longevity     Count Vectorizer       0.30    1.0        0.985424
#
#      Accuracy Test
# 225       0.981672
# 226       0.986249
# 227       0.985673
# 228       0.981660
# 229       0.985867

# %%
feat_2_cv.loc[feat_2_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                            0.1
# Alpha                                0.0
# Accuracy Train                   0.99223
# Accuracy Test                   0.997709
# Name: 325, dtype: object

# %%
feat_2_cv[(feat_2_cv["Alpha"] == 1.00)]
# Out:
#     Output Predicted Vectorization Method  Test Size  Alpha  Accuracy Train  \
# 225        Longevity     Count Vectorizer       0.10    1.0        0.985352
# 226        Longevity     Count Vectorizer       0.15    1.0        0.985840
# 227        Longevity     Count Vectorizer       0.20    1.0        0.984668
# 228        Longevity     Count Vectorizer       0.25    1.0        0.984105
# 229        Longevity     Count Vectorizer       0.30    1.0        0.985424
#
#      Accuracy Test
# 225       0.981672
# 226       0.986249
# 227       0.985673
# 228       0.981660
# 229       0.985867

# %%
feat_1_tf.loc[feat_1_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                     0.1
# Alpha                         0.0
# Accuracy Train           0.993122
# Accuracy Test            0.997709
# Name: 320, dtype: object

# %%
feat_1_tf[(feat_1_tf["Alpha"] == 1.00)]
# Out:
#     Output Predicted Vectorization Method  Test Size  Alpha  Accuracy Train  \
# 220        Longevity               TF-IDF       0.10    1.0        0.981404
# 221        Longevity               TF-IDF       0.15    1.0        0.980984
# 222        Longevity               TF-IDF       0.20    1.0        0.979940
# 223        Longevity               TF-IDF       0.25    1.0        0.979214
# 224        Longevity               TF-IDF       0.30    1.0        0.980020
#
#      Accuracy Test
# 220       0.964490
# 221       0.970206
# 222       0.969628
# 223       0.967905
# 224       0.970970

# %%
feat_2_tf.loc[feat_2_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                     0.1
# Alpha                         0.0
# Accuracy Train           0.993122
# Accuracy Test            0.997709
# Name: 320, dtype: object

# %%
feat_2_tf[(feat_2_tf["Alpha"] == 1.00)]
# Out:
#     Output Predicted Vectorization Method  Test Size  Alpha  Accuracy Train  \
# 220        Longevity               TF-IDF       0.10    1.0        0.981404
# 221        Longevity               TF-IDF       0.15    1.0        0.980984
# 222        Longevity               TF-IDF       0.20    1.0        0.979940
# 223        Longevity               TF-IDF       0.25    1.0        0.979214
# 224        Longevity               TF-IDF       0.30    1.0        0.980020
#
#      Accuracy Test
# 220       0.964490
# 221       0.970206
# 222       0.969628
# 223       0.967905
# 224       0.970970

# %% [markdown]
# # SVM

# %%
feat_1 = df_1_svm[df_1_svm['Output Predicted'] == 'Longevity']
feat_2 = df_2_svm[df_2_svm['Output Predicted'] == 'Longevity']
feat_3 = df_3_svm[df_3_svm['Output Predicted'] == 'Longevity']

feat_1_cv = feat_1[feat_1['Vectorization Method'] == 'Count Vectorizer'] ##
feat_1_tf = feat_1[feat_1['Vectorization Method'] == 'TF-IDF']
feat_2_cv = feat_2[feat_2['Vectorization Method'] == 'Count Vectorizer']
feat_2_tf = feat_2[feat_2['Vectorization Method'] == 'TF-IDF']
feat_3_cv = feat_3[feat_3['Vectorization Method'] == 'Count Vectorizer']
feat_3_tf = feat_3[feat_3['Vectorization Method'] == 'TF-IDF']

# %%
feat_1_cv.loc[feat_1_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                            0.1
# C Value                              1.8
# Accuracy Train                       1.0
# Accuracy Test                   0.996564
# Name: 270, dtype: object

# %%
feat_1_cv[(feat_1_cv["C Value"] == 0.90)]
# Out:
#     Output Predicted Vectorization Method  Test Size  C Value  Accuracy Train  \
# 33         Longevity     Count Vectorizer       0.30      0.9             1.0
# 93         Longevity     Count Vectorizer       0.25      0.9             1.0
# 153        Longevity     Count Vectorizer       0.20      0.9             1.0
# 213        Longevity     Count Vectorizer       0.15      0.9             1.0
# 273        Longevity     Count Vectorizer       0.10      0.9             1.0
#
#      Accuracy Test
# 33        0.995798
# 93        0.995415
# 153       0.994842
# 213       0.996180
# 273       0.996564

# %%
feat_2_cv.loc[feat_2_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                           0.15
# C value                              2.0
# Maximum iterations                 300.0
# Accuracy Train                       1.0
# Accuracy Test                    0.99618
# Name: 133, dtype: object

# %%
feat_2_cv[(feat_2_cv["C value"] == 0.90)]
# Out:
# Empty DataFrame
# Columns: [Output Predicted, Vectorization Method, Test Size, C value, Maximum iterations, Accuracy Train, Accuracy Test]
# Index: []

# %%
feat_3_cv.loc[feat_3_cv['Accuracy Test'].idxmax()]
# Out:
# Output Predicted               Longevity
# Vectorization Method    Count Vectorizer
# Test Size                           0.15
# C Value                             0.07
# Maximum iterations                  50.0
# Accuracy Train                       1.0
# Accuracy Test                    0.99618
# Name: 648, dtype: object

# %%
feat_3_cv[(feat_3_cv["C Value"] == 0.90)]
# Out:
# Empty DataFrame
# Columns: [Output Predicted, Vectorization Method, Test Size, C Value, Maximum iterations, Accuracy Train, Accuracy Test]
# Index: []

# %%
feat_1_tf.loc[feat_1_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                    0.25
# C Value                       1.8
# Accuracy Train                1.0
# Accuracy Test            0.998624
# Name: 84, dtype: object

# %%
feat_1_tf[(feat_1_tf["C Value"] == 0.90)]
# Out:
#     Output Predicted Vectorization Method  Test Size  C Value  Accuracy Train  \
# 27         Longevity               TF-IDF       0.30      0.9             1.0
# 87         Longevity               TF-IDF       0.25      0.9             1.0
# 147        Longevity               TF-IDF       0.20      0.9             1.0
# 207        Longevity               TF-IDF       0.15      0.9             1.0
# 267        Longevity               TF-IDF       0.10      0.9             1.0
#
#      Accuracy Test
# 27        0.997708
# 87        0.998624
# 147       0.998281
# 207       0.997708
# 267       0.997709

# %%
feat_2_tf.loc[feat_2_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                     0.1
# C value                       2.0
# Maximum iterations          300.0
# Accuracy Train           0.995032
# Accuracy Test            0.997709
# Name: 102, dtype: object

# %%
feat_2_tf[(feat_2_tf["C value"] == 0.90)]
# Out:
# Empty DataFrame
# Columns: [Output Predicted, Vectorization Method, Test Size, C value, Maximum iterations, Accuracy Train, Accuracy Test]
# Index: []

# %%
feat_3_tf.loc[feat_3_tf['Accuracy Test'].idxmax()]
# Out:
# Output Predicted        Longevity
# Vectorization Method       TF-IDF
# Test Size                     0.1
# C Value                      0.07
# Maximum iterations           50.0
# Accuracy Train           0.996179
# Accuracy Test            0.997709
# Name: 768, dtype: object

# %%
feat_3_tf[(feat_3_tf["C Value"] == 1.00)]
# Out:
# Empty DataFrame
# Columns: [Output Predicted, Vectorization Method, Test Size, C Value, Maximum iterations, Accuracy Train, Accuracy Test]
# Index: []
